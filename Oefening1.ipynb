# %% [markdown]
# # Hallo wereld! 🌍
#
# Welkom bij deze oefening! Je leert hier hoe je een naam bewaart in een 'variabele' en hoe je die op het scherm toont.
#
# Typ de volgende code in de cel hieronder en voer deze uit door op **Shift + Enter** te drukken:
#
# ```python
# naam = "Lisa"
# print("Hallo " + naam + "!")
# ```

# %%
naam = "Stefan"
print("Hallo " + naam + "!")
# Out:
# Hallo Stefan!

# %% [markdown]
# ### ✅ Variant
# Verander nu de variabele 'naam' door jouw eigen naam en voer het programma opnieuw uit.
